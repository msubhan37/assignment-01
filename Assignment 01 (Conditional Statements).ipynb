# %% [markdown]
# 1) A company decided to give bonus of 5% to employee if his/her year of service is more than 5 years.
# Ask user for their salary and year of service and print the net bonus amount.

# %%
salary = float(input("Enter your salary"))
service = float(input("Enter your service"))

if service > 5 :
    bonus = salary * 0.05
    print(f"congratulations your bonus is {bonus}")
else:
    print("sorry your service is not enough for bonus")
# Out:
# congratulations your bonus is 3500.0

# %% [markdown]
# 2) Write a program to check whether a person is eligible for voting or not. (accept age from user) if age is greater than 17 eligible otherwise not eligible

# %%
age= int(input("Enter your age"))

if  age > 17:
   print("you are eligible for vote")
else:
 print("you are note eligible for vote")
# Out:
# you are eligible for vote

# %% [markdown]
# 3) Write a program to check whether a number entered by user is even or odd.

# %%
num = float(input("Enter a number"))

if num % 2 == 0:
    print(f"{num} is even")
else:
    print(f"{num} is odd")
# Out:
# 4.0 is even

# %% [markdown]
# 4) Write a program to check whether a number is divisible by 7 or not.
# Show Answer

# %%
num = int(input("Enter a number"))

if num % 7 == 0:
    print("your number is compeletly divided by 7")
else:
    print(f"{num} is not divided by 7")
# Out:
# 8 is not divided by 7

# %% [markdown]
# 5) Write a program to display
# "Hello" if a number entered by user is a multiple of five , otherwise print "Bye".

# %%
num = int(input("Enter a number"))

if num % 5 == 0:
    print("Hello")
else:
    print("Bye")
# Out:
# Hello

# %% [markdown]
# 6. Take values of length and breadth of a rectangle from user and print if it is square or rectangle.

# %%
length = int(input("ENter a length"))
breadth = int(input("Enter a breadth"))

if length==breadth:
    print("It is a square")
else:
    print("It is a rectangle")
# Out:
# It is a rectangle

# %% [markdown]
# 7. Take two int values from user and print greatest among them.

# %%
num_1 = int(input("Enter your 1st number"))
num_2 = int(input("Enter your 2st number"))

if num_1 > num_2 :
    print(f"{num_1} is greater then {num_2}")
else:
    print(f"{num_1} is less then {num_2} ")
# Out:
# 4 is less then 9

# %% [markdown]
# 8. A school has following rules for grading system:
#
# a. Below 25 - F
#
# b. 25 to 45 - E
#
# c. 45 to 50 - D
#
# d. 50 to 60 - C
#
# e. 60 to 80 - B
#
# f. Above 80 - A
#
# Ask user to enter marks and print the corresponding grade.

# %%
grade = float(input("Enter your grade"))

if grade > 80 :
    print("Congratulations Your Grade Is A")
elif grade > 60 :
    print("Congratulations Your Grade Is B")
elif grade > 50 :
    print("Congratulations Your Grade Is C")
elif grade > 45 :
    print("Congratulations Your Grade Is D")
elif grade > 25 :
    print("Congratulations Your Grade Is E")
elif grade < 25 :
    print("Congratulations Your Are Fail")
# Out:
# Congratulations Your Are Fail

# %% [markdown]
# 9. Ask user to enter age, gender ( M or F ), marital status ( Y or N ) and then using following rules print their place of service.
#
# if employee is female, then she will work only in urban areas.
#
# if employee is a male and age is in between 20 to 40 then he may work in anywhere
#
# if employee is male and age is in between 40 t0 60 then he will work in urban areas only.
#
# And any other input of age should print "ERROR"

# %%
age = int(input("Enter your age"))
gender = input("Enter your gender (M or F):")
marital_status = input("ENter your marital status (Y or N):")

if gender == 'F' :
    print("you are work only urban areas")
elif 20 <= age < 40 and gender == 'M':
    print("you are work from any where")
elif 40 <= age <=60 and gender == 'M':
    print("you are work from only urban areas")
else:
    print("ERROR")
# Out:
# you are work from only urban areas
